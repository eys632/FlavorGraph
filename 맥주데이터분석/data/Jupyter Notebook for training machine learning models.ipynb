# %% [markdown]
# # Linear models run by Michiel for the ML paper
#
# Importing packages

# %%
import os
from platform import system
import pandas as pd
import numpy as np
from numpy.random import randint

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LassoCV, MultiTaskLassoCV
from sklearn.cross_decomposition import PLSRegression

from sklearn.multioutput import MultiOutputRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

from xgboost import XGBRegressor

from sklearn.svm import SVR

from sklearn.neural_network import MLPRegressor

import optuna

import pickle
import joblib

# %% [markdown]
# #### Working directory

# %%
os.chdir(os.path.join('my', 'directory'))

np.random.seed(42)

# %%
from init_modeling import generate_X
from init_modeling import regressor_performance, pickle_model

# %% [markdown]
# Creating required folders

# %%
for path in ['models', 'Model_performance', 'Optimal_settings']:
    if not os.path.exists(path):
        os.makedirs(path)

# %% [markdown]
# #### Test train split
# Comment/uncomment one of both sections to select the RateBeer or the Trained Panel sensory datasets.
# Note that the RateBeer dataset is not available without prior written permission from RateBeer (ZX Ventures, USA).

# %%
# chem_dataset_ratebeer = pd.read_csv('chem_dataset_ratebeer.csv').set_index('beer')
# x_name = 'chem_log'
# X = generate_X(pd.concat([chem_dataset_ratebeer['beer_id'], chem_dataset_ratebeer.loc[:,'acetaldehyde':'sulfur_sum']], axis=1), impute=True)
# y_name = 'ratebeer'
# Y = chem_dataset_ratebeer.loc[:,'ave_score_5':'overall_20']
# y_class = chem_dataset_ratebeer.loc[:,'tasting_category_fine']
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30,
#                                                     random_state=0, shuffle=True, stratify=y_class)

chem_dataset = pd.read_csv('Supplemental File S1.csv').set_index('beer')
trained_panel_dataset = pd.read_csv('Supplemental File S4.csv').set_index('beer')
chem_dataset_expertpanel = chem_dataset.join(trained_panel_dataset)
x_name = 'chem_log'
X = generate_X(pd.concat([chem_dataset_expertpanel['beer_id'] , chem_dataset_expertpanel.loc[:,'acetaldehyde':'sulfur_sum']], axis=1), impute=True)
y_name = 'expertpanel'
Y = chem_dataset_expertpanel.loc[:,'A_malt_all':'overall']
y_class = chem_dataset_expertpanel.loc[:,'tasting_category_fine']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30,
                                                    random_state=0, shuffle=True, stratify=y_class)

# %% [markdown]
# #### Scaling the data
# This is necessary for the Neural Network and Linear Models. Out of consistency, we do it for the whole dataset.

# %%
scaler_X = StandardScaler().fit(X_train)
# scaler_Y = StandardScaler().fit(Y_train)

X_train = scaler_X.transform(X_train)
X_test = scaler_X.transform(X_test)
# Y_train = scaler_Y.transform(Y_train)
# Y_test = scaler_Y.transform(Y_test)

# %% [markdown]
# Creating first order interaction terms

# %%
poly = PolynomialFeatures(interaction_only=True)

X_train_int = poly.fit_transform(X_train)
X_test_int = poly.fit_transform(X_test)

X_train_int = pd.DataFrame(X_train_int,columns=poly.get_feature_names_out()).drop('1', axis = 1)
X_test_int = pd.DataFrame(X_test_int,columns=poly.get_feature_names_out()).drop('1', axis = 1)

# %% [markdown]
# ### Linear model

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    regressor_loop = LinearRegression(fit_intercept=True, copy_X=True)
    regressor_loop.fit(X_train_int, Y_train_loop)

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train_int, Y_train_loop, X_test_int, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    joblib.dump(regressor_loop, os.path.join('models', f'Linear_regression_interaction_{aspect}_{y_name}.pkl'))

# Training full model
LM = LinearRegression(fit_intercept=True, copy_X=True).fit(X_train_int, Y_train)
mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train_int, Y_train, X_test_int, Y_test, LM, toprint = False)
aspect = 'everything'

joblib.dump(LM, os.path.join('models', f'Linear_regression_interaction_full_model_{y_name}.pkl'))

# Adding full model to the list
performance_loop.append(['Complete_LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Turning the list into a dataframe
performance_lr_df = pd.DataFrame(performance_loop,
                                 columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

# Saving
performance_lr_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_Linear_model_interactions.csv', index=False)
# Out:
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\1583913706.py:22: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Complete_LinearModel interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# %% [markdown]
# ### Lasso regression

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    regressor_loop = LassoCV(cv = 5, random_state = 0)
    regressor_loop.fit(X_train_int, Y_train_loop)

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train_int, Y_train_loop, X_test_int, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    joblib.dump(regressor_loop, os.path.join('models', f'Lasso_regression_interactions_{aspect}_{y_name}.pkl'))

# Training full model
lasso_cv = MultiTaskLassoCV(cv = 5, random_state = 0).fit(X_train_int, Y_train)
mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train_int, Y_train, X_test_int, Y_test, lasso_cv, toprint = False)
aspect = 'everything'

joblib.dump(lasso_cv, os.path.join('models', f'Lasso_regression_interactions_full_model_{y_name}.pkl'))

# Adding full model to the list
performance_loop.append(['Complete_Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Turning the list into a dataframe
performance_l1r_df = pd.DataFrame(performance_loop,
                                  columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

# Saving
performance_l1r_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_Lasso_interactions.csv', index=False)
# Out:
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.368e-03, tolerance: 6.243e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.917e-02, tolerance: 6.079e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.201e-03, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.616e-03, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.053e-02, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.255e-02, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.280e-02, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.373e-02, tolerance: 3.264e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.146e-03, tolerance: 3.305e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.507e-02, tolerance: 3.305e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.746e-02, tolerance: 3.305e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.975e-02, tolerance: 3.305e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.120e-02, tolerance: 3.305e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.314e-03, tolerance: 3.373e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.465e-03, tolerance: 2.556e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.239e-03, tolerance: 4.338e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.139e-03, tolerance: 4.569e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.490e-03, tolerance: 4.569e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.554e-03, tolerance: 3.508e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.658e-03, tolerance: 3.508e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.945e-03, tolerance: 3.508e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.586e-03, tolerance: 3.508e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.105e-03, tolerance: 6.033e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.135e-03, tolerance: 4.853e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.994e-03, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.310e-03, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.020e-03, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e-02, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.538e-02, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.427e-02, tolerance: 4.432e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.862e-03, tolerance: 2.483e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.403e-03, tolerance: 5.623e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.109e-03, tolerance: 5.623e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.058e-02, tolerance: 5.623e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.216e-02, tolerance: 5.623e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.367e-02, tolerance: 5.623e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.697e-03, tolerance: 6.337e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.696e-03, tolerance: 6.153e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.563e-03, tolerance: 6.153e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.844e-03, tolerance: 6.153e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.598e-03, tolerance: 6.596e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.094e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.851e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.300e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.581e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.884e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.171e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.093e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.101e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.390e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.540e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.747e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.792e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.681e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.635e-03, tolerance: 3.277e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.234e-03, tolerance: 3.552e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.062e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.873e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.895e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.878e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.852e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.769e-02, tolerance: 3.873e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.953e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.093e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.632e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.111e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.702e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.865e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.823e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.732e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.691e-03, tolerance: 1.668e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.055e-03, tolerance: 1.625e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.031e-03, tolerance: 1.625e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.896e-03, tolerance: 1.625e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.748e-03, tolerance: 1.764e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e-02, tolerance: 1.764e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.674e-02, tolerance: 1.764e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.789e-03, tolerance: 5.234e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.174e-02, tolerance: 5.234e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.434e-03, tolerance: 5.234e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.715e-03, tolerance: 4.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.722e-03, tolerance: 4.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.225e-03, tolerance: 4.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.110e-03, tolerance: 4.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.113e-03, tolerance: 4.851e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.607e-03, tolerance: 3.552e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.092e-03, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.095e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.263e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.234e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.366e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.623e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.147e-02, tolerance: 3.206e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.488e-03, tolerance: 3.970e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.368e-03, tolerance: 4.444e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.278e-02, tolerance: 4.444e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.479e-03, tolerance: 4.444e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.156e-03, tolerance: 4.444e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.178e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.243e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.352e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.947e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.561e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.627e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.839e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.976e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.482e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.527e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.211e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.163e-02, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.790e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.034e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.992e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.337e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.585e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.265e-03, tolerance: 4.131e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.202e-03, tolerance: 2.361e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.910e-03, tolerance: 2.490e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.999e-03, tolerance: 2.490e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.473e-03, tolerance: 3.223e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.358e-03, tolerance: 3.223e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.336e-03, tolerance: 3.223e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.639e-03, tolerance: 3.223e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.346e-03, tolerance: 3.172e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.308e-03, tolerance: 3.172e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.414e-03, tolerance: 3.172e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.854e-03, tolerance: 3.158e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.686e-03, tolerance: 3.158e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.161e-03, tolerance: 3.158e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.895e-03, tolerance: 3.158e-03
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.884e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.080e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.126e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.988e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.312e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.749e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.152e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.843e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.399e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.036e-03, tolerance: 2.650e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.438e-02, tolerance: 8.276e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.120e-03, tolerance: 5.196e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.282e-03, tolerance: 5.196e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.016e-02, tolerance: 5.196e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.241e-02, tolerance: 5.196e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.091e-02, tolerance: 5.196e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.953e-03, tolerance: 4.932e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.967e-03, tolerance: 4.932e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.052e-03, tolerance: 4.932e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.489e-03, tolerance: 4.932e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.007e-03, tolerance: 5.328e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.229e-03, tolerance: 5.328e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.281e-03, tolerance: 5.328e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.125e-03, tolerance: 5.328e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.478e-03, tolerance: 4.217e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.991e-03, tolerance: 4.217e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.826e-03, tolerance: 4.180e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.080e-03, tolerance: 4.180e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.190e-03, tolerance: 4.345e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.163e-03, tolerance: 4.345e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.825e-03, tolerance: 4.345e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.230e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.855e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.790e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.335e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.465e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.728e-02, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.893e-03, tolerance: 4.867e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.922e-03, tolerance: 4.902e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.822e-02, tolerance: 4.902e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.540e-02, tolerance: 4.902e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.053e-03, tolerance: 4.296e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.244e-02, tolerance: 4.296e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_10276\3252567603.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Lasso interactions', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# %% [markdown]
# ### Partial Least Squares
#
# For PLSR, grid search returned either the same or worse models. So we are using the native model.

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    regressor_loop = PLSRegression(scale=True)
    regressor_loop.fit_transform(X_train, Y_train_loop)

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=True)
    performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])


    joblib.dump(regressor_loop, os.path.join('models', f'PLS_regression_{aspect}_{y_name}.pkl'))

# Training full model
PLS = PLSRegression().fit(X_train, Y_train)
mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, PLS, toprint = False)
aspect = 'everything'

joblib.dump(PLS, os.path.join('models', f'Elasticnet_regression_full_model_{y_name}.pkl'))

# Adding full model to the list
performance_loop.append(['Complete_PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])



performance_pls_df = pd.DataFrame(performance_loop,
                                  columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_pls_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_Partial_Least_Squares_Regression.csv', index=False)
# Out:
# Training set performance:
# Mean squared error: 0.22099703547843583
# Coefficient of determination (R^2): 0.5095557222884579
#
# Test set performance:
# Mean squared error: 3.553249204378284
# Coefficient of determination (R^2): -4.457862941392433
#
#
#
# Training set performance:
# Mean squared error: 0.13644428454504237
# Coefficient of determination (R^2): 0.38091304793715564
#
# Test set performance:
# Mean squared error: 0.5107171504056026
# Coefficient of determination (R^2): -1.8468580520561866
#
#
#
# Training set performance:
# Mean squared error: 0.17898623728061946
# Coefficient of determination (R^2): 0.38683108997565163
#
# Test set performance:
# Mean squared error: 0.9634023181072183
# Coefficient of determination (R^2): -3.2541201040230945
#
#
#
# Training set performance:
# Mean squared error: 0.22245095287017574
# Coefficient of determination (R^2): 0.45129747451165125
#
# Test set performance:
# Mean squared error: 1.6965921978034602
# Coefficient of determination (R^2): -3.6815394885240673
#
#
#
# Training set performance:
# Mean squared error: 0.1700647116602862
# Coefficient of determination (R^2): 0.3703585602268734
#
# Test set performance:
# Mean squared error: 2.7608375553949296
# Coefficient of determination (R^2): -2.1448011624853747
#
#
#
# Training set performance:
# Mean squared error: 0.21385640557494395
# Coefficient of determination (R^2): 0.5098683066563071
#
# Test set performance:
# Mean squared error: 0.4527770427966859
# Coefficient of determination (R^2): -0.07665853254740718
#
#
#
# Training set performance:
# Mean squared error: 0.14173533407307878
# Coefficient of determination (R^2): 0.4093150981991648
#
# Test set performance:
# Mean squared error: 0.8869172999371974
# Coefficient of determination (R^2): -2.914838994476627
#
#
#
# Training set performance:
# Mean squared error: 0.2445305842752252
# Coefficient of determination (R^2): 0.40362121933641604
#
# Test set performance:
# Mean squared error: 0.6115182994119337
# Coefficient of determination (R^2): -1.234522408514482
#
#
#
# Training set performance:
# Mean squared error: 0.14343289148889177
# Coefficient of determination (R^2): 0.4847439823076338
#
# Test set performance:
# Mean squared error: 1.5041729692003911
# Coefficient of determination (R^2): -4.11134409839234
#
#
#
# Training set performance:
# Mean squared error: 0.07827293765970106
# Coefficient of determination (R^2): 0.3490214020218825
#
# Test set performance:
# Mean squared error: 0.5026330520380012
# Coefficient of determination (R^2): -1.955683689643413
#
#
#
# Training set performance:
# Mean squared error: 0.202524817133862
# Coefficient of determination (R^2): 0.40968998536038825
#
# Test set performance:
# Mean squared error: 2.6386356781462297
# Coefficient of determination (R^2): -5.614676384808389
#
#
#
# Training set performance:
# Mean squared error: 0.1681714041893429
# Coefficient of determination (R^2): 0.36119859926865017
#
# Test set performance:
# Mean squared error: 0.22165729746021082
# Coefficient of determination (R^2): -0.048245029078973545
#
#
#
# Training set performance:
# Mean squared error: 0.17894667431022554
# Coefficient of determination (R^2): 0.37903037040232723
#
# Test set performance:
# Mean squared error: 0.5760435111545562
# Coefficient of determination (R^2): -0.9882827764137403
#
#
#
# Training set performance:
# Mean squared error: 0.11808830110961464
# Coefficient of determination (R^2): 0.33030319683355414
#
# Test set performance:
# Mean squared error: 1.5162124035833413
# Coefficient of determination (R^2): -7.157092209940016
#
#
#
# Training set performance:
# Mean squared error: 0.14318092779721375
# Coefficient of determination (R^2): 0.3597062098380367
#
# Test set performance:
# Mean squared error: 0.24394543168463906
# Coefficient of determination (R^2): 0.24521547279550115
#
#
#
# Training set performance:
# Mean squared error: 0.20907226143096053
# Coefficient of determination (R^2): 0.5232625157155426
#
# Test set performance:
# Mean squared error: 4.088545787854731
# Coefficient of determination (R^2): -6.5758543963737
#
#
#
# Training set performance:
# Mean squared error: 0.14146100676393478
# Coefficient of determination (R^2): 0.3368305243391144
#
# Test set performance:
# Mean squared error: 0.3694283189284518
# Coefficient of determination (R^2): -1.1346724970416076
#
#
#
# Training set performance:
# Mean squared error: 0.13406544550188268
# Coefficient of determination (R^2): 0.4287703670537565
#
# Test set performance:
# Mean squared error: 1.7004581893431872
# Coefficient of determination (R^2): -6.040845625532225
#
#
#
# Training set performance:
# Mean squared error: 0.19208911881504703
# Coefficient of determination (R^2): 0.4502910228353283
#
# Test set performance:
# Mean squared error: 1.9354933104446435
# Coefficient of determination (R^2): -6.207815047302284
#
#
#
# Training set performance:
# Mean squared error: 0.21489942727635133
# Coefficient of determination (R^2): 0.39404925188980633
#
# Test set performance:
# Mean squared error: 2.6988780795412834
# Coefficient of determination (R^2): -2.8446059035919444
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# Training set performance:
# Mean squared error: 0.1942174977752369
# Coefficient of determination (R^2): 0.6164858592592712
#
# Test set performance:
# Mean squared error: 1.0689649985581984
# Coefficient of determination (R^2): -1.586405651113425
#
#
#
# Training set performance:
# Mean squared error: 0.11804560963674506
# Coefficient of determination (R^2): 0.40705156578783086
#
# Test set performance:
# Mean squared error: 0.2391272446239687
# Coefficient of determination (R^2): -0.17570079958988027
#
#
#
# Training set performance:
# Mean squared error: 0.14919452788241302
# Coefficient of determination (R^2): 0.4230025650220417
#
# Test set performance:
# Mean squared error: 0.8660732480297558
# Coefficient of determination (R^2): -2.3911774367832987
#
#
#
# Training set performance:
# Mean squared error: 0.18422362385851354
# Coefficient of determination (R^2): 0.5179550707140154
#
# Test set performance:
# Mean squared error: 0.7237206855020853
# Coefficient of determination (R^2): -1.0761084072120655
#
#
#
# Training set performance:
# Mean squared error: 0.14343870033897105
# Coefficient of determination (R^2): 0.3695314608070108
#
# Test set performance:
# Mean squared error: 0.5643631277936086
# Coefficient of determination (R^2): -2.0153974860328305
#
#
#
# Training set performance:
# Mean squared error: 0.17941612747503427
# Coefficient of determination (R^2): 0.48170388115083784
#
# Test set performance:
# Mean squared error: 0.20875102494671866
# Coefficient of determination (R^2): 0.3476238281223728
#
#
#
# Training set performance:
# Mean squared error: 0.14833604628576602
# Coefficient of determination (R^2): 0.40798965274527044
#
# Test set performance:
# Mean squared error: 0.858298649454166
# Coefficient of determination (R^2): -2.6623445137238146
#
#
#
# Training set performance:
# Mean squared error: 0.18285926251100534
# Coefficient of determination (R^2): 0.4564088745304662
#
# Test set performance:
# Mean squared error: 0.5249969151223665
# Coefficient of determination (R^2): -0.8740757640831407
#
#
#
# Training set performance:
# Mean squared error: 0.10608627031016876
# Coefficient of determination (R^2): 0.31702222115492373
#
# Test set performance:
# Mean squared error: 1.1342969710967012
# Coefficient of determination (R^2): -4.382248100723717
#
#
#
# Training set performance:
# Mean squared error: 0.129194953809889
# Coefficient of determination (R^2): 0.39320858510607537
#
# Test set performance:
# Mean squared error: 0.36406573768238487
# Coefficient of determination (R^2): -0.036338500535158635
#
#
#
# Training set performance:
# Mean squared error: 0.18618751884258952
# Coefficient of determination (R^2): 0.7364387343803759
#
# Test set performance:
# Mean squared error: 5.976435393447936
# Coefficient of determination (R^2): -6.499038011564621
#
#
#
# Training set performance:
# Mean squared error: 0.16055897715973785
# Coefficient of determination (R^2): 0.6830757793051956
#
# Test set performance:
# Mean squared error: 1.0423706227300111
# Coefficient of determination (R^2): -0.7620172093749731
#
#
#
# Training set performance:
# Mean squared error: 0.2645673507626576
# Coefficient of determination (R^2): 0.44503253653201946
#
# Test set performance:
# Mean squared error: 0.27102143172524573
# Coefficient of determination (R^2): 0.3620151569450729
#
#
#
# Training set performance:
# Mean squared error: 0.29621279767907877
# Coefficient of determination (R^2): 0.3622495409452726
#
# Test set performance:
# Mean squared error: 3.221568111359084
# Coefficient of determination (R^2): -8.878979684774436
#
#
#
# Training set performance:
# Mean squared error: 0.1820140247550354
# Coefficient of determination (R^2): 0.3915149193128036
#
# Test set performance:
# Mean squared error: 1.2274069778175594
# Coefficient of determination (R^2): -5.84209651230636
#
#
#
# Training set performance:
# Mean squared error: 0.1448828625910582
# Coefficient of determination (R^2): 0.421267339317973
#
# Test set performance:
# Mean squared error: 10.958682799045231
# Coefficient of determination (R^2): -43.6731121476601
#
#
#
# Training set performance:
# Mean squared error: 0.15193738993041525
# Coefficient of determination (R^2): 0.38734171844237464
#
# Test set performance:
# Mean squared error: 4.719858092258428
# Coefficient of determination (R^2): -21.734362863197973
#
#
#
# Training set performance:
# Mean squared error: 0.12845588900743238
# Coefficient of determination (R^2): 0.30700118955544553
#
# Test set performance:
# Mean squared error: 1.1415299948809605
# Coefficient of determination (R^2): -4.3320694538975175
#
#
#
# Training set performance:
# Mean squared error: 0.10135763743691352
# Coefficient of determination (R^2): 0.3786629186285947
#
# Test set performance:
# Mean squared error: 0.25946382243866706
# Coefficient of determination (R^2): -0.7326065741007708
#
#
#
# Training set performance:
# Mean squared error: 0.2426634127055165
# Coefficient of determination (R^2): 0.5235807036630289
#
# Test set performance:
# Mean squared error: 0.30459031310455864
# Coefficient of determination (R^2): 0.15807354235577575
#
#
#
# Training set performance:
# Mean squared error: 0.08127443052101772
# Coefficient of determination (R^2): 0.4707550962928281
#
# Test set performance:
# Mean squared error: 0.2565972406976565
# Coefficient of determination (R^2): 0.19937620767813713
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# Training set performance:
# Mean squared error: 0.21259492160376578
# Coefficient of determination (R^2): 0.42391334686657167
#
# Test set performance:
# Mean squared error: 1.756481659576624
# Coefficient of determination (R^2): -8.883754727924599
#
#
#
# Training set performance:
# Mean squared error: 0.10818507052586329
# Coefficient of determination (R^2): 0.7573777491061083
#
# Test set performance:
# Mean squared error: 5.948501878625458
# Coefficient of determination (R^2): -6.95851170684336
#
#
#
# Training set performance:
# Mean squared error: 0.16895177872070455
# Coefficient of determination (R^2): 0.6772540859095169
#
# Test set performance:
# Mean squared error: 15.596558121784346
# Coefficient of determination (R^2): -23.689415932100705
#
#
#
# Training set performance:
# Mean squared error: 0.13149989968699283
# Coefficient of determination (R^2): 0.3244719407505785
#
# Test set performance:
# Mean squared error: 1.4241326916995796
# Coefficient of determination (R^2): -5.634215819729146
#
#
#
# Training set performance:
# Mean squared error: 0.15385059233254839
# Coefficient of determination (R^2): 0.7380342343158266
#
# Test set performance:
# Mean squared error: 1.527515768789453
# Coefficient of determination (R^2): -1.8406777883160892
#
#
#
# Training set performance:
# Mean squared error: 0.14921025223803885
# Coefficient of determination (R^2): 0.589279132681297
#
# Test set performance:
# Mean squared error: 0.31075980773800516
# Coefficient of determination (R^2): 0.27756457084092023
#
#
#
# Training set performance:
# Mean squared error: 0.12449735843748401
# Coefficient of determination (R^2): 0.5931107459745902
#
# Test set performance:
# Mean squared error: 0.7504482160856797
# Coefficient of determination (R^2): -1.1500231275030286
#
#
#
# Training set performance:
# Mean squared error: 0.18377830978670398
# Coefficient of determination (R^2): 0.48965146516672375
#
# Test set performance:
# Mean squared error: 3.7939057660370494
# Coefficient of determination (R^2): -11.220741854187931
#
#
#
# Training set performance:
# Mean squared error: 0.16870316389235432
# Coefficient of determination (R^2): 0.4452690025244923
#
# Test set performance:
# Mean squared error: 7.93908365459562
# Coefficient of determination (R^2): -26.932119842978587
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:10: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])
# C:\Users\u0116955\AppData\Local\Temp\ipykernel_25544\720685712.py:23: RuntimeWarning: invalid value encountered in sqrt
#   performance_loop.append(['Complete_PLS', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# %% [markdown]
# ### AdaBoost

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [{'learning_rate': np.arange(0.2,2.0,0.2),
                   'loss': ['linear','square','exponential'],
                   'n_estimators': [200, 500, 1000],
                   }]
    grid_search_loop = GridSearchCV(AdaBoostRegressor(n_estimators=200, random_state=0),
                                    param_grid,
                                    cv=5,
                                    scoring='r2',
                                    verbose=1,
                                    refit=True,
                                    n_jobs=8)
    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['AdaBoost', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'Adaboost_regressor_{aspect}_{y_name}', regressor_loop, CV_results)

# Training full model
param_grid = [{'estimator__learning_rate': np.arange(0.2,2.0,0.2),
               'estimator__loss': ['linear','square','exponential'],
               'estimator__n_estimators': [200, 500, 1000],
               }]
grid_search = GridSearchCV(MultiOutputRegressor(AdaBoostRegressor(random_state=0)),
                           param_grid,
                           cv=5,
                           scoring='r2',
                           verbose=1,
                           refit=True,
                           n_jobs=8)

grid_search_results = grid_search.fit(X_train, Y_train)
adaboost = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, adaboost, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'Adaboost_regressor_full_model_{y_name}', adaboost, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_Adaboost', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])


# Creating the dataframe
performance_abr_df = pd.DataFrame(performance_loop,
                                  columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_abr_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_AdaBoost.csv', index=False)

# %% [markdown]
# ### GradientBoost

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [{'subsample': np.arange(0.2,1.0,0.2),
                   'learning_rate': np.arange(0.02,0.2,0.02),
                   'max_depth': np.arange(6,15,3),
                   'n_estimators': [200, 500, 1000],
                   'loss': ['squared_error', 'absolute_error']
                   }]
    grid_search_loop = GridSearchCV(GradientBoostingRegressor(random_state=0),
                                    param_grid,
                                    cv=5,
                                    scoring='r2',
                                    verbose=1,
                                    refit=True,
                                    return_train_score=True,
                                    n_jobs = 8)

    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['GradientBoost', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'Gradient_Boost_regressor_{aspect}_{y_name}', regressor_loop, CV_results)


# Training full model
param_grid = [{'estimator__subsample': np.arange(0.2,1.0,0.2),
               'estimator__learning_rate': np.arange(0.02,0.2,0.02),
               'estimator__max_depth': np.arange(6,15,3),
               'estimator__n_estimators': [200, 500, 1000],
               'estimator__loss': ['squared_error', 'absolute_error']
               }]
grid_search = GridSearchCV(MultiOutputRegressor(GradientBoostingRegressor(random_state=0)),
                           param_grid,
                           cv=5,
                           scoring='r2',
                           verbose=1,
                           refit=True,
                           return_train_score=True,
                           n_jobs = 8)

grid_search_results = grid_search.fit(X_train, Y_train)
gradientboost = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, gradientboost, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'Gradient_Boost_regressor_full_model_{y_name}', gradientboost, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_GradientBoost', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Creating the dataframe
performance_gb_df = pd.DataFrame(performance_loop,
                                  columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_gb_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_GradientBoost.csv', index=False)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 48
#      33 param_grid = [{'estimator__subsample': np.arange(0.2,1.0,0.2),
#      34                'estimator__learning_rate': np.arange(0.02,0.2,0.02),
#      35                'estimator__max_depth': np.arange(6,15,3),
#      36                'estimator__n_estimators': [200, 500, 1000],
#      37                'estimator__loss': ['squared_error', 'absolute_error']
#      38                }]
#      39 grid_search = GridSearchCV(MultiOutputRegressor(GradientBoostingRegressor(random_state=0)),
#      40                            param_grid,
#      41                            cv=5,
#    (...)
#      45                            return_train_score=True,
#      46                            n_jobs = 8)
# ---> 48 grid_search_results = grid_search.fit(X_train, Y_train)
#      49 gradientboost = grid_search_results.best_estimator_
#      51 mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, gradientboost, toprint = False)
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File C:\Workdir\Programs\Anaconda3\lib\site-packages\joblib\_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File C:\Workdir\Programs\Anaconda3\lib\concurrent\futures\_base.py:441, in Future.result(self, timeout)
#     438 elif self._state == FINISHED:
#     439     return self.__get_result()
# --> 441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     444     raise CancelledError()
#
# File C:\Workdir\Programs\Anaconda3\lib\threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Random Forest

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [
        {'max_features': np.arange(2,X_train.shape[1], 20),
         'max_depth': np.arange(4, 20, 2),
         'min_impurity_decrease': np.arange(0, 0.4, 0.05),
         'n_estimators' : [200, 500, 1000]},
    ]
    grid_search_loop = GridSearchCV(estimator=RandomForestRegressor(oob_score=True, random_state=0),
                                    param_grid=param_grid,
                                    cv=5,
                                    scoring= 'r2',
                                    refit=True,
                                    verbose=1,
                                    return_train_score=True,
                                    n_jobs = 8
                                    )
    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['RandomForest', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'Random_Forest_regressor_{aspect}_{y_name}', regressor_loop, CV_results)

# Training full model
param_grid = [
    {'max_features': np.arange(2,X_train.shape[1], 20),
     'max_depth': np.arange(4, 20, 2),
     'min_impurity_decrease': np.arange(0, 0.4, 0.05),
     'n_estimators' : [200, 500, 1000]},
]
grid_search = GridSearchCV(estimator=RandomForestRegressor(oob_score=True, random_state=0),
                           param_grid=param_grid,
                           cv=5,
                           scoring= 'r2',
                           refit=True,
                           verbose=1,
                           return_train_score=True,
                           n_jobs = 8
                           )

grid_search_results = grid_search.fit(X_train, Y_train)
random_forest = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, random_forest, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'Random_Forest_regressor_full_model_{y_name}', random_forest, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_RandomForest', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Creating the dataframe
performance_rf_df = pd.DataFrame(performance_loop,
                                 columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_rf_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_RandomForest.csv', index=False)

# %% [markdown]
# ### Extra Trees

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [
        {'max_features': np.arange(2, X_train.shape[1], 20),
         'max_depth': np.arange(4, 20, 2),
         'min_impurity_decrease': np.arange(0, 0.4, 0.05),
         'n_estimators': [200, 500, 1000]
         },
    ]
    grid_search_loop = GridSearchCV(estimator=ExtraTreesRegressor(bootstrap=True, oob_score=True,
                                                                  random_state=0),
                                    param_grid=param_grid,
                                    cv=5,
                                    scoring= 'r2',
                                    refit=True,
                                    verbose=1,
                                    n_jobs = 8,
                                    )
    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['ExtraTrees', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'Extra_Trees_regressor_{aspect}_{y_name}', regressor_loop, CV_results)

# Training full model
param_grid = [
    {'max_features': np.arange(2, X_train.shape[1], 20),
     'max_depth': np.arange(4, 20, 2),
     'min_impurity_decrease': np.arange(0, 0.4, 0.05),
     'n_estimators': [200, 500, 1000]
     },
]
grid_search = GridSearchCV(estimator=ExtraTreesRegressor(bootstrap=True, oob_score=True, random_state=0),
                           param_grid=param_grid,
                           cv=5,
                           scoring= 'r2',
                           refit=True,
                           verbose=1,
                           n_jobs = 8,
                           )

grid_search_results = grid_search.fit(X_train, Y_train)
extra_trees = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, extra_trees, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'Extra_Trees_regressor_full_model_{y_name}', extra_trees, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_ExtraTrees', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Creating the dataframe
performance_et_df = pd.DataFrame(performance_loop,
                                  columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_et_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_ExtraTrees.csv', index=False)

# %% [markdown]
# ### XGBOOST model

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [{'eta': [0.001, 0.005, 0.01, 0.05, 0.1, 0.3, 0.5],
                   'max_depth': np.arange(10)+1,
                   'n_estimators': [200, 500, 1000],
                   }]
    grid_search_loop = GridSearchCV(estimator=XGBRegressor(oob_score=True, random_state=0),
                                    param_grid=param_grid,
                                    cv=5,
                                    scoring= 'r2',
                                    refit=True,
                                    verbose=1,
                                    return_train_score=True,
                                    n_jobs = 8
                                    )
    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['RandomForest', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'XGBoost_regressor_{aspect}_{y_name}', regressor_loop, CV_results)

# Training full model
param_grid = [{'estimator__eta': [0.001, 0.005, 0.01, 0.05, 0.1, 0.3, 0.5],
               'estimator__max_depth': np.arange(10)+1,
               'estimator__n_estimators': [200, 500, 1000],
               }]
grid_search = GridSearchCV(estimator=MultiOutputRegressor(XGBRegressor(random_state=0)),
                           param_grid=param_grid,
                           cv=5,
                           scoring= 'r2',
                           refit=True,
                           verbose=1,
                           return_train_score=True,
                           n_jobs = 8
                           )

grid_search_results = grid_search.fit(X_train, Y_train)
XGBoost = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, random_forest, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'XGBoost_regressor_full_model_{y_name}', XGBoost, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_XGBoost', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Creating the dataframe
performance_xgb_df = pd.DataFrame(performance_loop,
                                 columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_xgb_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_XGBoost.csv', index=False)

# %% [markdown]
# ### Support Vector Regressor

# %%
performance_loop = []
for aspect in Y_train.columns:
    Y_train_loop = Y_train[aspect]
    Y_test_loop = Y_test[aspect]

    # search for best alpha and
    param_grid = [{'C': [0.001, 0.01, 0.1, 1, 10],
                   'epsilon': [0.01, 0.05, 0.1, 0.2],
                   'kernel': ['linear','poly','rbf'],
                   'degree': np.arange(2,5),
                   'gamma': np.arange(0.002,0.5,0.01)
                   }]
    grid_search_loop = GridSearchCV(SVR(),
                                    param_grid,
                                    cv=5,
                                    scoring='r2',
                                    verbose=1,
                                    refit=True,
                                    n_jobs = 8)

    grid_search_results = grid_search_loop.fit(X_train, Y_train_loop)
    regressor_loop = grid_search_results.best_estimator_

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train_loop, X_test, Y_test_loop, regressor_loop, toprint=False)
    performance_loop.append(['SupportVectorMachine', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

    CV_results = pd.DataFrame(grid_search_loop.cv_results_)
    pickle_model(f'Support_Vector_regressor_{aspect}_{y_name}', regressor_loop, CV_results)

# Training full model
param_grid = [{'estimator__C': [0.001, 0.01, 0.1, 1, 10],
               'estimator__epsilon': [0.01, 0.05, 0.1, 0.2],
               'estimator__kernel': ['linear','poly','rbf'],
               'estimator__degree': np.arange(2,5),
               'estimator__gamma': np.arange(0.002,0.5,0.01)
               }]
grid_search = GridSearchCV(MultiOutputRegressor(SVR()),
                           param_grid,
                           cv=5,
                           scoring='r2',
                           verbose=1,
                           refit=True,
                           n_jobs = 8)

grid_search_results = grid_search.fit(X_train, Y_train)
svm = grid_search_results.best_estimator_

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, svm, toprint = False)
aspect = 'everything'

CV_results = pd.DataFrame(grid_search.cv_results_)
pickle_model(f'Support_Vector_regressor_full_model_{y_name}', svm, CV_results)

# Adding full model to the list
performance_loop.append(['Complete_SupportVectorMachine', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])

# Creating the dataframe
performance_svm_df = pd.DataFrame(performance_loop,
                                 columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

performance_svm_df.to_csv(f'Model_performance/ModelPerformances_{x_name}_{y_name}_SupportVectorMachine.csv', index=False)

# %% [markdown]
# #### Test train split
# The neural network was particularly weak with the random state 0. Random state 1 greatly improved performance.

# %%
# chem_dataset_ratebeer = pd.read_csv('chem_dataset_complete_log_ratebeer.csv').set_index('beer')
# x_name = 'chem_log'
# X = generate_X(pd.concat([chem_dataset_ratebeer['beer_id'], chem_dataset_ratebeer.loc[:,'acetaldehyde':'sulfur_sum']], axis=1), impute=True)
# y_name = 'ratebeer'
# Y = chem_dataset_ratebeer.loc[:,'ave_score_5':'overall_20']
# y_class = chem_dataset_ratebeer.loc[:,'tasting_category_fine']
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30,
#                                                     random_state=1, shuffle=True, stratify=y_class)


chem_dataset_expertpanel = pd.read_csv('chem_dataset_complete_log_expertpanel.csv').set_index('beer')
x_name = 'chem_log'
X = generate_X(pd.concat([chem_dataset_expertpanel['beer_id'] , chem_dataset_expertpanel.loc[:,'acetaldehyde':'sulfur_sum']], axis=1), impute=True)
y_name = 'expertpanel'
Y = chem_dataset_expertpanel.loc[:,'A_malt_all':'overall']
y_class = chem_dataset_expertpanel.loc[:,'tasting_category_fine']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30,
                                                    random_state=1, shuffle=True, stratify=y_class)

# %% [markdown]
# ### Artificial Neural Network
# Creating and Optuna optimizer objective

# %%
Model_performance = []

#### TRAINING INDIVIDUAL MODELS

for aspect in Y_train.columns:

    ### Defining objective
    def objective(trial):
        n_layers = trial.suggest_int('n_layers', 1,10) # no. of hidden layers
        layers = []
        for i in range(n_layers):
            layers.append(trial.suggest_int('n_units_{}'.format(i+1), 20, 300, step = 40)) # no. of hidden units or neurons
        activation=trial.suggest_categorical('activation',['tanh', 'relu']) # activation function
        alpha=trial.suggest_float('alpha', 1e-4, 100, log = True) #L2 penalty (regularization term) parameter.
        # define classifier
        model =  MLPRegressor(random_state=1,
                              solver='adam',
                              activation=activation,
                              alpha=alpha,
                              hidden_layer_sizes=(layers),
                              max_iter=1000,
                              learning_rate='adaptive',
                              early_stopping=True)

        # Evaluating model performance
        scores = cross_val_score(model,
                                 X_train,
                                 Y_train[aspect],
                                 cv=KFold(n_splits=5,
                                          # random_state=1, # Uncomment if you want to set shuffle to True.
                                          shuffle=False),
                                 scoring='r2',
                                 n_jobs=8)
        r_squared = scores.mean()

        return r_squared

    ### Optmizing
    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=3000, n_jobs=8)

    ### Training model with optimal parameters
    architecture = []
    for i in range(study.best_params['n_layers']):
        architecture.append(study.best_params[f'n_units_{i+1}'])

    model = MLPRegressor(random_state=1,
                         solver='adam',
                         max_iter=1000,
                         learning_rate='adaptive',
                         early_stopping=True,
                         hidden_layer_sizes=architecture,
                         activation=study.best_params['activation'],
                         alpha=study.best_params['alpha'])

    model.fit(X_train, Y_train[aspect])

    joblib.dump(model, os.path.join('models', f'Optuna_Neural_network_model_adam_{y_name}_{aspect}.pkl'))

    myresults = study.best_params
    myresults['R2'] = regressor_performance(X_train, Y_train[aspect], X_test, Y_test[aspect], model, toprint = False)[3]
    mydf = pd.DataFrame.from_dict(myresults, orient = 'index')
    mydf.columns = ['optimal value']
    mydf.to_csv(f'Optimal_settings/Optimal_settings_neural_network_adam_{y_name}_{aspect}.csv')

    mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train[aspect], X_test, Y_test[aspect], model, toprint = False)
    Model_performance.append(['MLPRegressor', x_name, y_name, aspect, mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])


#### FULL MODEL

### Defining objective
def objective(trial):
    n_layers = trial.suggest_int('n_layers', 1,10) # no. of hidden layers
    layers = []
    for i in range(n_layers):
        layers.append(trial.suggest_int('n_units_{}'.format(i+1), 20, 300, step = 40)) # no. of hidden units or neurons
    activation=trial.suggest_categorical('activation',['tanh', 'relu']) # activation function
    alpha=trial.suggest_float('alpha', 1e-4, 100, log = True) #L2 penalty (regularization term) parameter.
    # define classifier
    model =  MLPRegressor(random_state=1,
                          solver='adam',
                          activation=activation,
                          alpha=alpha,
                          hidden_layer_sizes=(layers),
                          max_iter=1000,
                          learning_rate='adaptive',
                          early_stopping=True)

    # Evaluating model performance
    scores = cross_val_score(model,
                             X_train,
                             Y_train,
                             cv=KFold(n_splits=5,
                                      # random_state=1, # Uncomment if you want to set shuffle to True.
                                      shuffle=False),
                             scoring='r2',
                             n_jobs=8)
    r_squared = scores.mean()

    return r_squared

### Optmizing
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=3000, n_jobs=8)

### Training model with optimal parameters
architecture = []
for i in range(study.best_params['n_layers']):
    architecture.append(study.best_params[f'n_units_{i+1}'])

model = MLPRegressor(random_state=1,
                     solver='adam',
                     max_iter=1000,
                     learning_rate='adaptive',
                     early_stopping=True,
                     hidden_layer_sizes=architecture,
                     activation=study.best_params['activation'],
                     alpha=study.best_params['alpha'])

model.fit(X_train, Y_train)

joblib.dump(model, os.path.join('models', f'Optuna_Neural_network_full_model_adam_{y_name}.pkl'))

myresults = study.best_params
myresults['R2'] = regressor_performance(X_train, Y_train, X_test, Y_test, model)[3]
mydf = pd.DataFrame.from_dict(myresults, orient = 'index')
mydf.columns = ['optimal value']
mydf.to_csv(f'Optimal_settings/Optimal_settings_neural_network_adam_full_model_{y_name}.csv')

mse_train, r2_train, mse_test, r2_test = regressor_performance(X_train, Y_train, X_test, Y_test, model, toprint = False)
Model_performance.append(['Complete_MLPRegressor',x_name, y_name, 'everything', mse_train, r2_train, np.sqrt(r2_train), mse_test, r2_test, np.sqrt(r2_test)])


## Saving model performance
Performance = pd.DataFrame(Model_performance,
                           columns=['regressor','X', 'Y', 'aspect', 'mse_train', 'r2_train', 'r_train', 'mse_test', 'r2_test', 'r_test'])

Performance.to_csv(f'Model_Performance/ModelPerformances_{x_name}_{y_name}_MLPRegressor.csv', index=False)
